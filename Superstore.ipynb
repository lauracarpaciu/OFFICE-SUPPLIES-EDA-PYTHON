# %%
import numpy as np 
import pandas as pd
store_df=pd.read_csv('C:/Users/Mirela/Downloads/Superstore/Superstore.csv',  encoding = "ISO-8859-1")

# %%
# Viewing data

# %%
store_df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
store_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
# The columns of the resulting DataFrame have different dtypes:

# %%
store_df.tail(5)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9989    9990  CA-2014-110422  1/21/2014  1/23/2014    Second Class
# 9990    9991  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9991    9992  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9992    9993  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9993    9994  CA-2017-119914   5/4/2017   5/9/2017    Second Class
#
#      Customer ID     Customer Name   Segment        Country         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
store_df.index
# Out:
# RangeIndex(start=0, stop=9994, step=1)

# %%
store_df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
store_df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
# Sort

# %%
store_df.sort_values(by="Order Date")
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 8074    8075  CA-2017-151750   1/1/2017   1/5/2017  Standard Class
# 848      849  CA-2017-107503   1/1/2017   1/6/2017  Standard Class
# 8075    8076  CA-2017-151750   1/1/2017   1/5/2017  Standard Class
# 8073    8074  CA-2017-151750   1/1/2017   1/5/2017  Standard Class
# 8071    8072  CA-2017-151750   1/1/2017   1/5/2017  Standard Class
# ...      ...             ...        ...        ...             ...
# 7875    7876  CA-2017-168403   9/9/2017  9/15/2017  Standard Class
# 5441    5442  CA-2017-155929   9/9/2017  9/13/2017  Standard Class
# 6255    6256  CA-2017-139444   9/9/2017  9/15/2017  Standard Class
# 8753    8754  CA-2017-152198   9/9/2017  9/10/2017     First Class
# 7876    7877  CA-2017-168403   9/9/2017  9/15/2017  Standard Class
#
#      Customer ID    Customer Name    Segment        Country        City  ...  \
# 8074    JM-15250     Janet Martin   Consumer  United States  Huntsville  ...
# ...

# %%
# DataFrame.sort_values() sorts by values:

# %%
# Selection

# %%
# Getting

# %%
# Selection by label

# %%
store_df.loc[:, ["Region", "Product Name",'Sales', 'Quantity', 'Discount', 'Profit']].sort_values(by="Region")
# Out:
#        Region                                       Product Name    Sales  \
# 2594  Central  Tyvek Side-Opening Peel & Seel Expanding Envel...  180.960
# 8943  Central                  Hon Comfortask Task/Swivel Chairs  239.358
# 6665  Central                                         Xerox 1914  219.840
# 2923  Central                                            Staples    6.080
# 2922  Central                             GBC Instant Report Kit    3.882
# ...       ...                                                ...      ...
# 3225     West  Letter or Legal Size Expandable Poly String Ti...   12.768
# 3224     West                   Bose SoundLink Bluetooth Speaker  318.400
# 7793     West                                         Xerox 1930   32.400
# 3247     West                     Col-Erase Pencils with Erasers   18.240
# 9993     West  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.160
#
#       Quantity  Discount    Profit
# 2594         2       0.0   81.4320
# ...

# %%
# Selection by position

# %%
store_df.iloc[:, [1,7,8,9]]
# Out:
#             Order ID    Segment        Country             City
# 0     CA-2016-152156   Consumer  United States        Henderson
# 1     CA-2016-152156   Consumer  United States        Henderson
# 2     CA-2016-138688  Corporate  United States      Los Angeles
# 3     US-2015-108966   Consumer  United States  Fort Lauderdale
# 4     US-2015-108966   Consumer  United States  Fort Lauderdale
# ...              ...        ...            ...              ...
# 9989  CA-2014-110422   Consumer  United States            Miami
# 9990  CA-2017-121258   Consumer  United States       Costa Mesa
# 9991  CA-2017-121258   Consumer  United States       Costa Mesa
# 9992  CA-2017-121258   Consumer  United States       Costa Mesa
# 9993  CA-2017-119914   Consumer  United States      Westminster
#
# [9994 rows x 4 columns]

# %%
# Boolean indexing

# %%
store_df[store_df['Quantity'] > 5]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 5          6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 7          8  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 10        11  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 16        17  CA-2014-105893  11/11/2014  11/18/2014  Standard Class
# 21        22  CA-2016-137330   12/9/2016  12/13/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9974    9975  US-2016-103674   12/6/2016  12/10/2016  Standard Class
# 9977    9978  US-2016-103674   12/6/2016  12/10/2016  Standard Class
# 9979    9980  US-2016-103674   12/6/2016  12/10/2016  Standard Class
# 9982    9983  US-2016-157728   9/22/2016   9/28/2016  Standard Class
# 9984    9985  CA-2015-100251   5/17/2015   5/23/2015  Standard Class
#
#      Customer ID     Customer Name      Segment        Country          City  \
# ...

# %%
store_df[store_df["Region"].isin(["South", "West"])]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
# Missing data

# %%
store_df.fillna(value=0)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
# Missing data

# %%
pd.isna(store_df)
# Out:
#       Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# 0      False     False       False      False      False        False
# 1      False     False       False      False      False        False
# 2      False     False       False      False      False        False
# 3      False     False       False      False      False        False
# 4      False     False       False      False      False        False
# ...      ...       ...         ...        ...        ...          ...
# 9989   False     False       False      False      False        False
# 9990   False     False       False      False      False        False
# 9991   False     False       False      False      False        False
# 9992   False     False       False      False      False        False
# 9993   False     False       False      False      False        False
#
#       Customer Name  Segment  Country   City  ...  Postal Code  Region  \
# ...

# %%
store_df.mean()
# Out:
# Row ID          4997.500000
# Postal Code    55190.379428
# Sales            229.858001
# Quantity           3.789574
# Discount           0.156203
# Profit            28.656896
# dtype: float64

# %%
# Value counts (histogramming) / mode

# %%
store_df["Product ID"].value_counts()
# Out:
# OFF-PA-10001970    19
# TEC-AC-10003832    18
# FUR-FU-10004270    16
# FUR-CH-10001146    15
# TEC-AC-10003628    15
#                    ..
# OFF-PA-10001661     1
# TEC-MA-10001570     1
# OFF-PA-10000048     1
# TEC-PH-10001949     1
# OFF-EN-10004206     1
# Name: Product ID, Length: 1862, dtype: int64

# %%
# Grouping

# %%
store_df.groupby("Segment")[["Sales", "Quantity"]].sum()
# Out:
#                     Sales  Quantity
# Segment
# Consumer     1.161401e+06     19521
# Corporate    7.061464e+05     11608
# Home Office  4.296531e+05      6744

# %%
store_df.groupby(["Segment", "Quantity"])[["Sales", "Profit"]].sum()
# Out:
#                             Sales      Profit
# Segment     Quantity
# Consumer    1          27060.9409   2604.5362
#             2         145326.4684  16144.9808
#             3         218331.6111  30417.5499
#             4         171472.5852  24817.6500
#             5         216480.1065  23168.8015
#             6          92880.5820   2709.8232
#             7         112396.1188  15373.8235
#             8          60388.8560   2304.6960
#             9          59129.0811   6713.2071
#             10          6932.6400    384.7850
#             11          6462.6100   1473.1739
#             12          8242.6320   1065.9192
#             13         28467.3610   5376.2501
#             14          7829.7520   1564.0128
# Corporate   1          15201.8972   2585.7225
#             2          90716.0496  12413.3406
#             3         128120.8929  15628.0644
#             4          80542.7476   6384.7292
#             5         140870.4050  20676.0360
# ...

# %%
df = store_df[:5]

# %%
stacked = df.stack()
stacked
stacked.to_csv("stack.csv")

# %%
pd.pivot_table(store_df, values="Sales", index=["Order ID", "Product ID"], columns=["Category"])
# Out:
# Category                        Furniture  Office Supplies  Technology
# Order ID       Product ID
# CA-2014-100006 TEC-PH-10002075        NaN              NaN     377.970
# CA-2014-100090 FUR-TA-10003715    502.488              NaN         NaN
#                OFF-BI-10001597        NaN          196.704         NaN
# CA-2014-100293 OFF-PA-10000176        NaN           91.056         NaN
# CA-2014-100328 OFF-BI-10000343        NaN            3.928         NaN
# ...                                   ...              ...         ...
# US-2017-169551 OFF-PA-10004100        NaN           15.552         NaN
#                OFF-ST-10004835        NaN           13.392         NaN
#                TEC-AC-10002018        NaN              NaN      16.776
#                TEC-AC-10003033        NaN              NaN     527.920
#                TEC-PH-10001363        NaN              NaN     683.988
#
# [9986 rows x 3 columns]

# %%
pd.pivot_table(store_df, values="Sales", index=["Order ID", "Product ID"], columns=["Segment"])
# Out:
# Segment                         Consumer  Corporate  Home Office
# Order ID       Product ID
# CA-2014-100006 TEC-PH-10002075   377.970        NaN          NaN
# CA-2014-100090 FUR-TA-10003715       NaN    502.488          NaN
#                OFF-BI-10001597       NaN    196.704          NaN
# CA-2014-100293 OFF-PA-10000176       NaN        NaN       91.056
# CA-2014-100328 OFF-BI-10000343     3.928        NaN          NaN
# ...                                  ...        ...          ...
# US-2017-169551 OFF-PA-10004100    15.552        NaN          NaN
#                OFF-ST-10004835    13.392        NaN          NaN
#                TEC-AC-10002018    16.776        NaN          NaN
#                TEC-AC-10003033   527.920        NaN          NaN
#                TEC-PH-10001363   683.988        NaN          NaN
#
# [9986 rows x 3 columns]

# %%
store_df.to_csv("foo.csv")
